# %% [markdown]
# # Clase Grafo (Esqueleto)
# Implementa los métodos solicitados para trabajar con grafos.

# %%
class Grafo:
    def __init__(self):
        # Conjunto de nodos
        self.nodos = set()
        # Lista de aristas (tuplas: origen, destino, peso opcional)
        self.aristas = []

    def añadir_vertice(self, vertice):
        # TODO: Implementar
        pass

    def añadir_arista(self, origen, destino, peso=None):
        # TODO: Implementar
        pass

    def eliminar_vertice(self, vertice):
        # TODO: Implementar
        pass

    def eliminar_arista(self, origen, destino):
        # TODO: Implementar
        pass

    def adyacentes(self, vertice):
        # TODO: Implementar
        pass

    def peso(self, origen, destino):
        # TODO: Implementar
        pass
