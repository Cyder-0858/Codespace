# %% [markdown]
# # Montículos y Colas de Prioridad en Python
#
# ## Objetivos del tema
#
# - Comprender qué es un montículo (heap) y cómo se representa en una lista.
# - Implementar un montículo en Python como estructura de datos.
# - Utilizar el montículo para construir una cola de prioridad.
# - Aplicar la cola de prioridad a un problema narrativo ambientado en el universo de Star Wars.
# - Desarrollar habilidades de programación orientada a objetos y manipulación de estructuras dinámicas.
# - Explorar algoritmos de ordenación basados en montículos (Heapsort).

# %% [markdown]
# ## ¿Qué es un montículo?
#
# Un montículo es una estructura de datos basada en un árbol binario completo que permite acceder rápidamente al elemento de mayor (o menor) prioridad.
#
# ### Tipos de montículos:
# - **Montículo máximo**: el valor de cada nodo es mayor o igual que el de sus hijos.
# - **Montículo mínimo**: el valor de cada nodo es menor o igual que el de sus hijos.
#
# ### Representación en listas:
# - Padre de `i`: `(i - 1) // 2`
# - Hijo izquierdo de `i`: `2 * i + 1`
# - Hijo derecho de `i`: `2 * i + 2`

# %%
## INSTRUCCIONES PARA COMPLETAR LA PRÁCTICA

### 📋 **TAREAS A REALIZAR:**

1. **Implementar la clase `Monticulo`:**
   - Completar todos los métodos marcados con `# TODO`
   - Seguir las instrucciones detalladas en cada método
   - Usar las fórmulas proporcionadas para navegación del árbol

2. **Implementar la clase `ColaPrioridad`:**
   - Entender el mecanismo de tuplas para mantener orden FIFO
   - Implementar el contador negativo para desempate
   - Usar el montículo interno para gestionar prioridades

3. **Probar las implementaciones:**
   - Descomentar el código del ejercicio de la base Starkiller
   - Ejecutar la prueba FIFO para verificar el orden correcto
   - Comprobar que las operaciones se atienden según su prioridad

### 🎯 **CONCEPTOS CLAVE A DOMINAR:**

- **Navegación en montículo:** Padre: `(i-1)//2`, Hijos: `2*i+1` y `2*i+2`
- **Flotación:** Mover elemento hacia arriba si es mayor que su padre
- **Hundimiento:** Mover elemento hacia abajo si es menor que sus hijos
- **Orden FIFO:** Usar tupla `(prioridad, -contador, dato)` para desempate
- **Comparación lexicográfica:** Python compara tuplas elemento por elemento

### 🚀 **ORDEN DE IMPLEMENTACIÓN SUGERIDO:**

1. `Monticulo.__init__()` y `vacio()`
2. `Monticulo.insertar()` y `_flotar()`
3. `Monticulo.borrar()` y `_hundir()`
4. `Monticulo.generar()` y `ordena()`
5. `ColaPrioridad.__init__()` y `vacia()`
6. `ColaPrioridad.agregar()` y `atender()`
7. Probar con el ejercicio de Star Wars

## Preguntas para reflexionar

1. ¿Qué ventajas ofrece un montículo frente a otras estructuras como listas o pilas para gestionar prioridades?
2. ¿Por qué es útil representar un árbol binario completo como una lista?
3. ¿Qué condiciones deben cumplirse para que un montículo sea válido?
4. ¿Cómo se relaciona el montículo con la cola de prioridad?
5. ¿Qué tipo de problemas reales pueden modelarse con colas de prioridad?

# %%
class Monticulo:
    def __init__(self):
        """
        INICIALIZACIÓN DEL MONTÍCULO
        ============================
        Inicializa la estructura interna del montículo.
        
        INSTRUCCIONES:
        - Crear una lista vacía para almacenar los elementos del montículo
        - Esta lista representará el árbol binario completo en forma de array
        
        PISTA: Un montículo se puede representar eficientemente con una lista
        """
        # TODO: Inicializar la lista de datos del montículo
        pass

    @staticmethod
    def generar(lista):
        """
        GENERACIÓN DE MONTÍCULO DESDE LISTA
        ===================================
        Genera un montículo a partir de una lista desordenada.
        
        INSTRUCCIONES:
        1. Crear una nueva instancia de montículo
        2. Insertar cada elemento de la lista usando el método insertar()
        3. Retornar el montículo generado
        
        PARÁMETROS:
        - lista: Lista de elementos para crear el montículo
        
        RETORNA:
        - Instancia de Monticulo con todos los elementos insertados
        """
        # TODO: Implementar la generación del montículo
        pass

    def insertar(self, elemento):
        """
        INSERCIÓN EN EL MONTÍCULO
        =========================
        Inserta un elemento en el montículo manteniendo la propiedad de montículo máximo.
        
        INSTRUCCIONES:
        1. Agregar el elemento al final de la lista (posición len(datos))
        2. Hacer "flotar" el elemento hacia arriba usando _flotar()
        3. El índice del nuevo elemento será len(datos) - 1
        
        ALGORITMO:
        - Agregar → Flotar → Mantener propiedad de montículo
        
        PARÁMETROS:
        - elemento: Elemento a insertar en el montículo
        """
        # TODO: Agregar elemento al final de la lista
        # TODO: Llamar a _flotar() con el índice del nuevo elemento
        pass

    def _flotar(self, i):
        """
        FLOTACIÓN DE ELEMENTO
        =====================
        Hace flotar el elemento en la posición i si es mayor que su padre.
        
        🔍 COMPARACIÓN DE TUPLAS EN FLOTACIÓN:
        =====================================
        Cuando trabajamos con ColaPrioridad, self.datos[i] contiene tuplas: (prioridad, -contador, dato)
        
        La comparación self.datos[i] > self.datos[padre] funciona automáticamente:
        1. Python compara elemento por elemento (comparación lexicográfica)
        2. Primero compara prioridades: si 3 > 2, entonces (3, -x, dato) > (2, -y, dato)
        3. Si las prioridades son iguales, compara contadores: si -0 > -1, entonces sale primero
        4. Python maneja esta comparación automáticamente, ¡no necesitas código especial!
        
        Ejemplo: 
        - Elemento hijo: (2, -0, "Primera tarea prioridad 2")    # Llegó primero
        - Elemento padre: (2, -1, "Segunda tarea prioridad 2")   # Llegó después
        - Comparación: (2, -0, ...) > (2, -1, ...) → True, por lo que flota el hijo
        
        INSTRUCCIONES:
        1. Mientras el índice i > 0 (no es la raíz):
           a. Calcular índice del padre: (i - 1) // 2
           b. Si datos[i] > datos[padre]: intercambiar elementos
           c. Actualizar i = índice del padre
           d. Si no hay intercambio, salir del bucle
        
        FÓRMULAS IMPORTANTES:
        - Padre de i: (i - 1) // 2
        - Comparación: elemento hijo > elemento padre (¡automática para tuplas!)
        
        PARÁMETROS:
        - i: Índice del elemento a hacer flotar
        """
        # TODO: Implementar la flotación del elemento
        # NOTA: La comparación datos[i] > datos[padre] funcionará automáticamente con tuplas
        pass

    def borrar(self):
        """
        ELIMINACIÓN DE LA RAÍZ
        ======================
        Elimina y devuelve el elemento de mayor prioridad (la raíz).
        
        INSTRUCCIONES:
        1. Verificar si el montículo está vacío → retornar None
        2. Guardar el elemento raíz (posición 0)
        3. Tomar el último elemento y ponerlo en la raíz
        4. Eliminar el último elemento de la lista
        5. Si el montículo no está vacío, hacer "hundir" desde la raíz
        6. Retornar el elemento raíz guardado
        
        ALGORITMO:
        - Guardar raíz → Mover último a raíz → Eliminar último → Hundir → Retornar raíz
        
        RETORNA:
        - El elemento de mayor prioridad, o None si está vacío
        """
        # TODO: Implementar la eliminación de la raíz
        pass

    def _hundir(self, i):
        """
        HUNDIMIENTO DE ELEMENTO
        =======================
        Hace hundir el elemento en la posición i si es menor que alguno de sus hijos.
        
        🔍 COMPARACIÓN DE TUPLAS EN HUNDIMIENTO:
        =======================================
        Durante el hundimiento, mantenemos el orden FIFO usando comparación lexicográfica:
        
        Para mantener FIFO con igual prioridad:
        - Las comparaciones datos[hijo] > datos[mayor] siguen siendo automáticas
        - Si un padre tiene prioridad 2 y un hijo también tiene prioridad 2:
          * Python compara automáticamente el segundo elemento (contador negativo)
          * El hijo con contador más negativo (llegó después) NO hundiría al padre
          * El hijo con contador menos negativo (llegó antes) SÍ hundiría al padre
        
        Ejemplo durante hundimiento:
        - Padre: (2, -5, "Sexta tarea")     # Llegó sexto con prioridad 2
        - Hijo:  (2, -3, "Cuarta tarea")   # Llegó cuarto con prioridad 2
        - Comparación: (2, -3, ...) > (2, -5, ...) → True
        - El hijo "sube" y el padre "baja", manteniendo orden FIFO
        
        INSTRUCCIONES:
        1. Crear un bucle infinito
        2. Calcular índices de hijos: hijo_izq = 2*i+1, hijo_der = 2*i+2
        3. Inicializar mayor = i
        4. Si hijo_izq existe y datos[hijo_izq] > datos[mayor]: mayor = hijo_izq
        5. Si hijo_der existe y datos[hijo_der] > datos[mayor]: mayor = hijo_der
        6. Si mayor == i: romper bucle (no hay intercambio)
        7. Intercambiar datos[i] con datos[mayor]
        8. Actualizar i = mayor
        
        FÓRMULAS IMPORTANTES:
        - Hijo izquierdo de i: 2 * i + 1
        - Hijo derecho de i: 2 * i + 2
        - Verificar límites: hijo < len(datos)
        - Comparación: ¡automática para tuplas!
        
        PARÁMETROS:
        - i: Índice del elemento a hacer hundir
        """
        # TODO: Implementar el hundimiento del elemento
        # NOTA: Las comparaciones datos[hijo] > datos[mayor] funcionarán automáticamente con tuplas
        pass

    def vacio(self):
        """
        VERIFICACIÓN DE MONTÍCULO VACÍO
        ===============================
        Devuelve True si el montículo está vacío.
        
        INSTRUCCIONES:
        - Verificar si la longitud de la lista de datos es 0
        
        RETORNA:
        - True si está vacío, False en caso contrario
        """
        # TODO: Verificar si la lista de datos está vacía
        pass

    @staticmethod
    def ordena(lista):
        """
        ALGORITMO HEAPSORT
        ==================
        Ordena una lista usando un montículo (algoritmo Heapsort).
        
        INSTRUCCIONES:
        1. Generar un montículo a partir de la lista
        2. Crear una lista resultado vacía
        3. Mientras el montículo no esté vacío:
           a. Borrar el elemento de mayor prioridad
           b. Insertarlo al inicio de la lista resultado
        4. Retornar la lista resultado
        
        NOTA: Se inserta al inicio para obtener orden descendente
        (mayor a menor)
        
        PARÁMETROS:
        - lista: Lista a ordenar
        
        RETORNA:
        - Lista ordenada en orden descendente
        """
        # TODO: Implementar el algoritmo Heapsort
        pass

# %% [markdown]
# ##Colas de prioridad
# ###Una cola de prioridad es una estructura FIFO, donde los elementos tienen asociada una prioridad de forma que el primero será el primero que llegó con máxima prioridad.

# %%
class ColaPrioridad:
    def __init__(self):
        """
        INICIALIZACIÓN DE COLA DE PRIORIDAD
        ===================================
        Inicializa la cola de prioridad usando un montículo.
        
        INSTRUCCIONES:
        1. Crear una instancia de Monticulo()
        2. Inicializar un contador en 0 para mantener orden FIFO
        
        CONCEPTO CLAVE - ORDEN FIFO CON IGUAL PRIORIDAD:
        ===============================================
        Para garantizar que elementos con igual prioridad salgan en orden
        de llegada (FIFO), usaremos un contador como "desempate".
        """
        # TODO: Crear montículo interno
        # TODO: Inicializar contador para orden FIFO
        pass

    def agregar(self, prioridad, dato):
        """
        AGREGAR ELEMENTO CON PRIORIDAD
        ==============================
        Agrega un dato con su prioridad a la cola manteniendo orden FIFO.
        
        MECANISMO FIFO PARA IGUAL PRIORIDAD:
        ====================================
        Para mantener el orden de llegada cuando hay elementos con la misma prioridad,
        se utiliza una tupla de 3 elementos: (prioridad, -contador, dato)
        
        ¿POR QUÉ FUNCIONA ESTE MECANISMO?
        1. PRIORIDAD (primer elemento): Determina qué elementos se atienden primero
        2. -CONTADOR (segundo elemento): Actúa como "desempate" para igual prioridad
           - Se usa NEGATIVO (-self.contador) porque el montículo es MÁXIMO
           - El elemento que llegó PRIMERO tiene contador más BAJO
           - Al negarlo, se convierte en valor más ALTO en el montículo
           - Ejemplo: primer elemento contador=0 → -0=0 (mayor)
                     segundo elemento contador=1 → -1=-1 (menor)
        3. DATO (tercer elemento): La información real que queremos almacenar
        
        INSTRUCCIONES:
        1. Crear tupla: (prioridad, -self.contador, dato)
        2. Insertar la tupla en el montículo
        3. Incrementar el contador
        
        EJEMPLO DE FUNCIONAMIENTO:
        - Agregar("A", prioridad=2) → tupla: (2, -0, "A")
        - Agregar("B", prioridad=2) → tupla: (2, -1, "B")  
        - Agregar("C", prioridad=2) → tupla: (2, -2, "C")
        
        En el montículo máximo:
        - Primero se comparan prioridades: 2 = 2 = 2 (empate)
        - Luego se comparan contadores: 0 > -1 > -2
        - Por tanto, el orden de salida será: A, B, C (FIFO)
        
        PARÁMETROS:
        - prioridad: Nivel de prioridad del elemento (mayor número = mayor prioridad)
        - dato: Información a almacenar en la cola
        """
        # TODO: Crear tupla (prioridad, -contador, dato)
        # TODO: Insertar tupla en el montículo
        # TODO: Incrementar contador
        pass

    def atender(self):
        """
        ATENDER ELEMENTO DE MAYOR PRIORIDAD
        ===================================
        Atiende el elemento de mayor prioridad respetando FIFO para igual prioridad.
        
        PROCESO DE ELIMINACIÓN:
        ======================
        1. El montículo automáticamente devuelve la tupla con mayor valor
        2. La comparación de tuplas en Python es lexicográfica:
           - Primero compara elemento [0] (prioridad)
           - Si hay empate, compara elemento [1] (contador negativo)
           - El contador negativo asegura que el primer elemento agregado salga primero
        3. Extraemos solo el dato (índice 2) de la tupla resultado
        
        INSTRUCCIONES:
        1. Verificar si la cola está vacía → retornar None
        2. Borrar elemento del montículo (retorna tupla)
        3. Extraer y retornar solo el dato (índice 2 de la tupla)
        
        EJEMPLO DE EXTRACCIÓN:
        - Montículo contiene: [(3, -0, "Tarea Snoke"), (2, -0, "Tarea Phasma")]  
        - Se extrae: (3, -0, "Tarea Snoke")
        - Se retorna: "Tarea Snoke"
        
        RETORNA:
        - El dato del elemento de mayor prioridad, o None si está vacía
        """
        # TODO: Verificar si está vacía
        # TODO: Borrar elemento del montículo (obtener tupla)
        # TODO: Retornar solo el dato (índice 2)
        pass

    def vacia(self):
        """
        VERIFICACIÓN DE COLA VACÍA
        ==========================
        Devuelve True si la cola está vacía.
        
        INSTRUCCIONES:
        - Verificar si el montículo interno está vacío
        
        RETORNA:
        - True si está vacía, False en caso contrario
        """
        # TODO: Verificar si el montículo está vacío
        pass

# %%
"""
🔍 CONCEPTO FUNDAMENTAL: COMPARACIÓN DE TUPLAS EN PYTHON
========================================================

Para entender completamente cómo funciona el mecanismo FIFO en la cola de prioridad,
es ESENCIAL comprender cómo Python compara las tuplas.

COMPARACIÓN LEXICOGRÁFICA DE TUPLAS:
===================================
Python compara tuplas elemento por elemento, de izquierda a derecha, usando
el mismo principio que se usa para ordenar palabras en un diccionario.

ALGORITMO DE COMPARACIÓN:
1. Compara el primer elemento de ambas tuplas
2. Si son diferentes → la tupla con mayor primer elemento es "mayor"
3. Si son iguales → pasa al segundo elemento y repite
4. Continúa hasta encontrar una diferencia o agotar elementos

EJEMPLOS PRÁCTICOS:
==================

Ejemplo 1 - Diferente prioridad:
tupla_a = (3, -0, "Tarea Snoke")
tupla_b = (2, -0, "Tarea Phasma")
tupla_a > tupla_b → True (porque 3 > 2)

Ejemplo 2 - Igual prioridad, diferente contador:
tupla_a = (2, -0, "Primera tarea")    # Llegó primero (contador=0)
tupla_b = (2, -1, "Segunda tarea")    # Llegó después (contador=1)
tupla_a > tupla_b → True (porque 2==2, pero -0 > -1)

Ejemplo 3 - Todo igual excepto el dato:
tupla_a = (2, -0, "Tarea Z")
tupla_b = (2, -0, "Tarea A")
tupla_a > tupla_b → True (porque 2==2, -0==-0, pero "Tarea Z" > "Tarea A")

APLICACIÓN EN NUESTRO MONTÍCULO:
===============================
En el montículo máximo, el elemento "mayor" siempre está en la raíz.
Al usar tuplas (prioridad, -contador, dato), garantizamos:

1. PRIORIDAD PRINCIPAL: Mayor prioridad = mayor tupla
2. ORDEN FIFO: Menor contador (negativo) = mayor tupla para igual prioridad  
3. DETERMINÍSTICO: Siempre hay un ganador claro

PASO A PASO PARA (2, -0, "A") vs (2, -1, "B"):
1. Comparar prioridades: 2 == 2 → Empate, continuar
2. Comparar contadores: -0 > -1 → ¡Ganador! (2, -0, "A") es mayor
3. No necesita comparar el tercer elemento

¡Por eso el elemento que llegó PRIMERO (contador 0) tiene mayor prioridad
que el que llegó DESPUÉS (contador 1) cuando tienen la misma prioridad!
"""

print("Ejemplo interactivo de comparación de tuplas:")
print("=" * 50)

# Simular tuplas como las que usaría la cola de prioridad
tupla1 = (3, -0, "Operación Snoke")
tupla2 = (2, -0, "Operación Phasma") 
tupla3 = (2, -1, "Segunda operación Phasma")

print(f"tupla1: {tupla1}")
print(f"tupla2: {tupla2}")
print(f"tupla3: {tupla3}")
print()

print("Comparaciones:")
print(f"tupla1 > tupla2: {tupla1 > tupla2} (Diferente prioridad: 3 > 2)")
print(f"tupla2 > tupla3: {tupla2 > tupla3} (Igual prioridad: -0 > -1)")
print(f"tupla1 > tupla3: {tupla1 > tupla3} (Diferente prioridad: 3 > 2)")

print("\n¡Orden del montículo máximo sería: tupla1, tupla2, tupla3!")

# %% [markdown]
# ## Ejercicio práctico: base Starkiller
# ###El general Hux es la persona encargada de administrar todas las operaciones de la base Starki- ller, para lo cual nos solicita desarrollar un algoritmo que permita controlar las actividades que se realizan, contemplando lo siguiente:
#
# a.	debe contemplar distintas prioridades para el control de operaciones de acuerdo al siguien- te criterio: pedidos de líder supremo Snoke y de Kylo Ren nivel tres, de capitán Phasma nivel dos y el resto de las operaciones nivel a cargo de los generales de la base de nivel uno;
#
# b.	de cada actividad se conoce quien es el encargado, una descripción, la hora y opcional- mente la cantidad de Stormtroopers requeridos;
#
# c.	utilizar una cola de prioridad para administrar las distintas operaciones, debe cargar al menos ocho: dos de nivel tres, cuatro de nivel dos y cuatro de nivel uno;
#
# d.	opcionalmente se podrán agregar operaciones luego de atender una;
#
# e.	realizar la atención de las operaciones de la cola;
#
# f.	luego de atender la quinta operación, agregar una operación solicitada por capitán Phasma para revisión de intrusos en el hangar B7 que requiere 25 Stormstroopers;
#
# g.	luego de atender la sexta operación, agregar una operación solicitada por el líder supremo Snoke para destruir el planeta Takodana.

# %%
class Operacion:
    def __init__(self, encargado, descripcion, hora, stormtroopers=None):
        self.encargado = encargado
        self.descripcion = descripcion
        self.hora = hora
        self.stormtroopers = stormtroopers

    def __str__(self):
        texto = f"{self.descripcion} (Encargado: {self.encargado}, Hora: {self.hora})"
        if self.stormtroopers:
            texto += f", Stormtroopers requeridos: {self.stormtroopers}"
        return texto

# %%
"""
EJERCICIO PRÁCTICO: SISTEMA DE OPERACIONES DE LA BASE STARKILLER
================================================================

INSTRUCCIONES PARA COMPLETAR EL EJERCICIO:
1. Completar la implementación de las clases Monticulo y ColaPrioridad
2. Ejecutar este código para probar el funcionamiento
3. Verificar que las operaciones se atienden en el orden correcto:
   - Primero por prioridad (3 > 2 > 1)
   - Dentro de la misma prioridad, por orden de llegada (FIFO)

RESULTADO ESPERADO:
- Las operaciones de Snoke y Kylo Ren (prioridad 3) salen primero
- Las operaciones de Phasma (prioridad 2) salen segundo
- Las operaciones de General Hux (prioridad 1) salen último
- Dentro de cada prioridad, se respeta el orden de llegada
"""

# Crear operaciones como instancias de la clase Operacion
operaciones = [
    (3, Operacion("Snoke", "Revisión de sistemas de defensa", "08:00")),
    (3, Operacion("Kylo Ren", "Inspección de tropas", "09:00")),
    (2, Operacion("Phasma", "Entrenamiento de escuadra", "10:00")),
    (2, Operacion("Phasma", "Revisión de armamento", "11:00")),
    (2, Operacion("Phasma", "Supervisión de patrullas", "12:00")),
    (2, Operacion("Phasma", "Control de accesos", "13:00")),
    (1, Operacion("General Hux", "Informe diario", "14:00")),
    (1, Operacion("General Hux", "Revisión de suministros", "15:00")),
    (1, Operacion("General Hux", "Planificación de misiones", "16:00")),
    (1, Operacion("General Hux", "Evaluación de personal", "17:00")),
]

# TODO: Crear la cola de prioridad (descomentar cuando hayas implementado la clase)
# cola = ColaPrioridad()

# TODO: Cargar las operaciones (descomentar cuando hayas implementado agregar())
# print("Cargando operaciones iniciales:")
# for prioridad, op in operaciones:
#     cola.agregar(prioridad, op)
#     print(f"  - Prioridad {prioridad}: {op}")

# TODO: Atender operaciones (descomentar cuando hayas implementado atender())
# print(f"\n=== ATENDIENDO OPERACIONES ===")
# contador_operaciones = 0
# while not cola.vacia():
#     op = cola.atender()
#     contador_operaciones += 1
#     print(f"Operación {contador_operaciones}: {op}")

#     if contador_operaciones == 5:
#         nueva_op = Operacion("Phasma", "Revisión de intrusos en el hangar B7", "18:00", stormtroopers=25)
#         cola.agregar(2, nueva_op)
#         print("  -> AGREGADA: Revisión de intrusos en el hangar B7")
    
#     if contador_operaciones == 6:
#         nueva_op = Operacion("Snoke", "Destrucción del planeta Takodana", "19:00")
#         cola.agregar(3, nueva_op)
#         print("  -> AGREGADA: Destrucción del planeta Takodana")

print("EJERCICIO LISTO PARA IMPLEMENTAR")
print("Completa las clases Monticulo y ColaPrioridad, luego descomenta este código para probarlo")

# %%
"""
PRUEBA DETALLADA DEL COMPORTAMIENTO FIFO
========================================

Esta celda contiene una prueba específica para verificar que la cola de prioridad
mantiene el orden FIFO (First In, First Out) para elementos con igual prioridad.

OBJETIVO DE LA PRUEBA:
- Agregar varios elementos con la misma prioridad
- Verificar que salen en el mismo orden en que entraron
- Comprobar que las prioridades diferentes se respetan

EJEMPLO DETALLADO DEL MECANISMO FIFO:
====================================

Al agregar elementos, internamente se crean estas tuplas en el montículo:

1. cola_prueba.agregar(2, "Primer elemento de prioridad 2")
   → Tupla: (2, -0, "Primer elemento de prioridad 2")

2. cola_prueba.agregar(2, "Segundo elemento de prioridad 2") 
   → Tupla: (2, -1, "Segundo elemento de prioridad 2")

3. cola_prueba.agregar(2, "Tercer elemento de prioridad 2")
   → Tupla: (2, -2, "Tercer elemento de prioridad 2")

4. cola_prueba.agregar(1, "Elemento de prioridad 1")
   → Tupla: (1, -3, "Elemento de prioridad 1")

5. cola_prueba.agregar(2, "Cuarto elemento de prioridad 2")
   → Tupla: (2, -4, "Cuarto elemento de prioridad 2")

ORDEN DE EXTRACCIÓN ESPERADO (montículo máximo con comparación lexicográfica):
1º: (2, -0, "Primer elemento...") - Prioridad 2, llegó primero  
2º: (2, -1, "Segundo elemento...") - Prioridad 2, llegó segundo
3º: (2, -2, "Tercer elemento...") - Prioridad 2, llegó tercero
4º: (2, -4, "Cuarto elemento...") - Prioridad 2, llegó quinto
5º: (1, -3, "Elemento prioridad 1") - Prioridad 1, llegó cuarto

¡FIFO mantenido para elementos de igual prioridad!
"""

# TODO: Descomenta este código cuando hayas implementado ColaPrioridad

# print("\n=== PRUEBA FIFO CON ELEMENTOS DE IGUAL PRIORIDAD ===")
# cola_prueba = ColaPrioridad()

# # Agregar elementos para probar FIFO
# cola_prueba.agregar(2, "Primer elemento de prioridad 2")
# cola_prueba.agregar(2, "Segundo elemento de prioridad 2") 
# cola_prueba.agregar(2, "Tercer elemento de prioridad 2")
# cola_prueba.agregar(1, "Elemento de prioridad 1")
# cola_prueba.agregar(2, "Cuarto elemento de prioridad 2")

# print("Orden de salida (debería ser FIFO para igual prioridad):")
# while not cola_prueba.vacia():
#     elemento = cola_prueba.atender()
#     print(f"  - {elemento}")

print("PRUEBA FIFO LISTA PARA EJECUTAR")
print("Descomenta el código de arriba cuando hayas completado la implementación")
